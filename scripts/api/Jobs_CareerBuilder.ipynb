# %% [markdown]
# # Getting Data from JobSearch CB API

# %%
import pandas as pd
import requests
import xmltodict
import json
from os import path, pardir
import settings
import sys
import datetime
from pandas.io.json import json_normalize

# %% [markdown]
# Read in the dataframe from the jobsearch

# %%
master_df = pd.io.pickle.read_pickle(path.join(pardir, pardir, 'data', 'tiff_jobs_Feb9.pkl'))
master_df.head()
# Out:
#                          ApplyRequirements     City                 Company  \
# 0   {u'ApplyRequirement': u'CanBulkApply'}  Oakland  Robert Half Technology
# 3     {u'ApplyRequirement': u'IsExternal'}  Oakland   Accounting Principals
# 6     {u'ApplyRequirement': u'IsExternal'}  Oakland                   Modis
# 9     {u'ApplyRequirement': u'IsExternal'}  Oakland             Citi Trends
# 12    {u'ApplyRequirement': u'IsExternal'}  Oakland          Another Source
#
#              CompanyDID                                  CompanyDetailsURL  \
# 0   cht3vg6lk6nkvvrxlrm  http://www.careerbuilder.com/jobs/company/cht3...
# 3   c8e3x36n4lbw1gwz78p  http://www.careerbuilder.com/jobs/company/c8e3...
# 6   chr3v363mh81q66v48m  http://www.careerbuilder.com/jobs/company/chr3...
# 9   chl6hr6f7l9qtw8h946  http://www.careerbuilder.com/jobs/company/chl6...
# 12  c8e0rh6t5hcrxtgbn8c  http://www.careerbuilder.com/jobs/company/c8e0...
#
#                                       CompanyImageURL                  DID  \
# 0   http://emj.icbdr.com/mediamanagement/p4/mvt57h...  J3L1YW6LG8DR87J3WLT
# 3   http://emj.icbdr.com/mediamanagement/h9/mxr479...  J3G5Z05X952ZGB4TZLS
# 6   http://emj.icbdr.com/mediamanagement/ll/mvl1tp...  J3H05D648THMYDN6PQF
# 9   http://emj.icbdr.com/mediamanagement/5k/mvm6pk...  JB75N56Y5PLLBR2WRT9
# 12  http://emj.icbdr.com/mediamanagement/6t/i8c546...  J3J05G688JZ7SZGLD40
#
#                                     DescriptionTeaser DisplayCity Distance  \
# 0   Ref ID: 00340-152866 Classification: Software ...        None  7 miles
# 3   Accounts Payable Supervisor The Accounts Payab...        None  7 miles
# 6   Established and still innovative organization ...        None  7 miles
# 9   Citi Trends is looking for a dedicated Store M...        None  7 miles
# 12  Another Source’s client, University of Califor...        None  7 miles
#
#      ...    LocationLatitude LocationLongitude  \
# 0    ...             37.8087         -122.2989
# 3    ...             37.8087         -122.2989
# 6    ...             37.8087         -122.2989
# 9    ...             37.8087         -122.2989
# 12   ...             37.8087         -122.2989
#
#                                  ONetFriendlyTitle    OnetCode  \
# 0          Information Technology Project Managers  15-1099.11
# 3   Supervisors of Office and Administrative Staff  43-1011.00
# 6        Computer Software Engineers, Applications  15-1031.00
# 9                Supervisors of Retail Sales Staff  41-1011.00
# 12                             Purchasing Managers  11-3061.00
#
#                      Pay PostedDate            PostedTime  \
# 0                    N/A   2/9/2015  2/9/2015 11:26:20 AM
# 3   $25.00 - $34.00/hour   2/6/2015   2/6/2015 8:42:26 PM
# 6     $105k - $130k/year   2/3/2015   2/3/2015 5:13:22 PM
# 9                    N/A  1/24/2015  1/24/2015 1:09:29 AM
# 12                   N/A  1/23/2015  1/23/2015 7:37:22 PM
#
#                                        SimilarJobsURL  \
# 0   http://www.careerbuilder.com/jobs/similarjobs....
# 3   http://www.careerbuilder.com/jobs/similarjobs....
# 6   http://www.careerbuilder.com/jobs/similarjobs....
# 9   http://www.careerbuilder.com/jobs/similarjobs....
# 12  http://www.careerbuilder.com/jobs/similarjobs....
#
#                                                Skills State
# 0   {u'Skill': [u'web development', u'html', u'agi...    CA
# 3                                                None    CA
# 6   {u'Skill': [u'apache http server', u'apache so...    CA
# 9     {u'Skill': [u'Communication', u'Retail sales']}    CA
# 12  {u'Skill': [u'Interpersonal skills', u'Supply ...    CA
#
# [5 rows x 29 columns]

# %% [markdown]
# Get the job descriptions that we've already called

# %%
if path.isfile(path.join(pardir, pardir, 'data', 'job_descriptions.pkl')):
    obtained_jobs = pd.io.pickle.read_pickle(path.join(pardir, 'data', 'job_descriptions.pkl'))
    obtained = set([job_id.encode('ascii', 'ignore') for job_id in obtained_jobs.DID])
else:
    obtained_jobs = pd.DataFrame()
    obtained = set()

# %% [markdown]
# Create sets of the job ids already found to be invalid

# %%
if path.isfile(path.join(pardir, 'data', 'invalid_job_ids.pkl')):
    invalid = set(pd.io.pickle.read_pickle(path.join(pardir, 'data', 'invalid_job_ids.pkl')))
else:
    invalid = set()

# %% [markdown]
# Create a list of job ids for which we still need to obtain descriptions

# %%
job_ids = [job_id.encode('ascii', 'ignore') for job_id in master_df.DID]
job_ids = [job_id for job_id in job_ids if job_id not in invalid and job_id not in obtained]

# %%
def get_jobs(num_jobs=500, invalid=invalid):
    daily_jobs_call = pd.DataFrame()
    for i, job_id in enumerate(job_ids):
        parameters = {'DeveloperKey': settings.CB_API_KEY, 
                      'DID': job_id}
        r = requests.get('http://api.careerbuilder.com/v3/job/', params=parameters)
        o = xmltodict.parse(r.content)
        j = json.dumps(o)
        raw_df = pd.read_json(j)
        if 'Job' in raw_df.index:
            new_df = json_normalize(raw_df.T.Job)
            daily_jobs_call = pd.concat([daily_jobs_call, new_df], ignore_index=True)
        else:
            invalid.add(job_id)
        if i == num_jobs - 1:
            break
    return daily_jobs_call, invalid

# %%
jobs, invalid = get_jobs(num_jobs=500)

# %%
jobs.head()
# Out:
#                                             ApplyURL BasicJobBranding  \
# 0  http://api.careerbuilder.com/v1/application/ap...             None
# 1  http://api.careerbuilder.com/v1/application/ap...             None
# 2  http://api.careerbuilder.com/v1/application/ap...             None
# 3  http://api.careerbuilder.com/v1/application/ap...             None
# 4  http://api.careerbuilder.com/v1/application/ap...             None
#
#    BeginDate                         BlankApplicationServiceURL  \
# 0   2/9/2015  http://api.careerbuilder.com/v1/application/bl...
# 1   2/6/2015  http://api.careerbuilder.com/v1/application/bl...
# 2   2/3/2015  http://api.careerbuilder.com/v1/application/bl...
# 3  1/24/2015  http://api.careerbuilder.com/v1/application/bl...
# 4  1/23/2015  http://api.careerbuilder.com/v1/application/bl...
#
#                                           Categories    CategoriesCodes  \
# 0      Engineering,  Information Technology,  Design  JN004,JN008,JN021
# 1                      Accounting,  Admin - Clerical        JN001,JN002
# 2               Information Technology,  Engineering        JN008,JN004
# 3             Retail,  Management,  General Business  JN033,JN037,JN006
# 4  Information Technology,  Purchasing - Procurem...  JN008,JN016,JN014
#
#                   Company           CompanyDID  \
# 0  Robert Half Technology  CHT3VG6LK6NKVVRXLRM
# 1   Accounting Principals  C8E3X36N4LBW1GWZ78P
# 2                   Modis  CHR3V363MH81Q66V48M
# 3             Citi Trends  CHL6HR6F7L9QTW8H946
# 4          Another Source  C8E0RH6T5HCRXTGBN8C
#
#                                    CompanyDetailsURL  \
# 0  http://www.careerbuilder.com/jobs/company/cht3...
# 1  http://www.careerbuilder.com/jobs/company/c8e3...
# 2  http://www.careerbuilder.com/jobs/company/chr3...
# 3  http://www.careerbuilder.com/jobs/company/chl6...
# 4  http://www.careerbuilder.com/jobs/company/c8e0...
#
#                                      CompanyImageURL  \
# 0                                               None
# 1  http://emj.icbdr.com/MediaManagement/J4/MXD6P8...
# 2  http://emj.icbdr.com/MediaManagement/SL/MR85F1...
# 3  http://emj.icbdr.com/MediaManagement/LY/MYP89R...
# 4  http://emj.icbdr.com/MediaManagement/X2/MWV20D...
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#                PayHighLowFormatted PayLow.Money.Amount  \
# 0                              N/A                0.00
# 1            $25.00 - $34.00 /Hour               25.00
# 2  $105,000.00 - $130,000.00 /Year           105000.00
# 3                              N/A                0.00
# 4                              N/A                0.00
#
#   PayLow.Money.CurrencyCode PayLow.Money.FormattedAmount PayOther PayPer  \
# 0                       USD                        $0.00      DOE   Year
# 1                       USD                       $25.00     None   Hour
# 2                       USD                  $105,000.00     None   Year
# 3                       USD                        $0.00     None   Year
# 4                       USD                        $0.00     None   Year
#
#                                   PrinterFriendlyURL RelocationCovered  \
# 0  http://api.careerbuilder.com/v1/joblink?Tracki...             False
# 1  http://api.careerbuilder.com/v1/joblink?Tracki...             False
# 2  http://api.careerbuilder.com/v1/joblink?Tracki...             False
# 3  http://api.careerbuilder.com/v1/joblink?Tracki...             False
# 4  http://api.careerbuilder.com/v1/joblink?Tracki...             False
#
#   TravelRequired TravelRequiredCode
# 0  Not Specified               RTNS
# 1  Not Specified               RTNS
# 2  Not Specified               RTNS
# 3     Negligible             RT3210
# 4  Not Specified               RTNS
#
# [5 rows x 66 columns]

# %%
len(jobs)
# Out:
# 490

# %% [markdown]
# If there are invalid job ids, write them to a pkl file

# %%
if invalid:
    invalid_series = pd.Series(list(invalid))
    invalid_series.to_pickle(path.join(pardir, pardir, 'data', 'invalid_job_ids.pickle'))

# %% [markdown]
# Write today's job calls to a file

# %%
filetime = str(datetime.datetime.now()).replace(' ', '_').replace(':', '_').replace('.','_').replace('-','_')[:16]
jobs.to_pickle(path.join(pardir, pardir, 'data', 'no_git','jobs_call_' + filetime + '.pkl'))

# %% [markdown]
# Write jobs obtained to date to a file

# %%
all_jobs = pd.concat([obtained_jobs, jobs], ignore_index=True)
all_jobs.to_pickle(path.join(pardir, pardir, 'data', 'job_descriptions.pkl'))
