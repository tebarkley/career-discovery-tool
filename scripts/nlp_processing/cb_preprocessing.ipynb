# %% [markdown]
# This notebook takes in a pickle file of raw inputs from the career builder API and outputs a dataframe indexed by the job ID containing the following columns: text, sentences, and words. The purpose is to put data into a standardized format for downstream analysis.

# %%
import nltk
import re
from os import path, pardir
import pandas as pd
from pandas import DataFrame, Series
import numpy as np
from bs4 import BeautifulSoup

# %%
def visible_text(element):
    if element.parent.name in ['style', 'script', '[document]', 'head', 'title']:
        return ''
    #get rid of tags
    result = re.sub('<br>|<br \/>|<p\/?>|<\/?li>', '\n', str(element.encode('ascii', 'ignore')))
    result = re.sub('<.*?>', ' ', result, flags=re.DOTALL)
    #add single quotes
    result = re.sub('&rsquo;', "'", result)
    #get rid of extra spaces, html spaces, and bullets
    result = re.sub(' {2,}|&nbsp;|&bull;', ' ', result)
    #replace multiple newlines with single newline
    result = re.sub('\s{2,}|\t', '\n', result)
    #add in double quotes
    result = re.sub('&ldquo;', '"', result)
    result = re.sub('&rdquo;', '"', result)
    result = re.sub('&rdquo;', '"', result)
    return result

#function for cleaning up HTML into text
def rawToText(description):
    soup = BeautifulSoup(description)
    texts = soup.findAll(text=True)
    visible_elements = [visible_text(elem) for elem in texts]
    text = ''.join(visible_elements)
    return text

#function for splitting sentences on new lines
def splitNewLine(sents):
    final_sents = []
    for sent in sents:
        sub_sents = sent.split('\n')
        for sub in sub_sents:
            if sub != '':
                final_sents.append(sub)
    return final_sents

#function for splitting sentences on semi-colon
def splitSemicolon(sents):
    final_sents = []
    for sent in sents:
        sub_sents = sent.split(';')
        for sub in sub_sents:
            if sub != '':
                final_sents.append(sub)
    return final_sents

# %%
def tokenizeCB(path_to_pkl_df, path_to_output_df):
    data = pd.read_pickle(path_to_pkl_df)
    #create simplified dataframe with just post ID and job description text
    post = data[['DID', 'JobDescription']]
    post.set_index('DID', inplace=True)
    post.columns = ['raw_text']
    #Add a column with better HTML
    post['html'] = post.raw_text.map(lambda x: BeautifulSoup(x).getText())
    #Add a column with just text:  http://stackoverflow.com/questions/10524387/beautifulsoup-get-text-does-not-strip-all-tags-and-javascript
    post['text'] = post.raw_text.apply(rawToText)
    #Add a column containing a list of sentences
    post['sents'] = post.text.map(lambda x: nltk.sent_tokenize(x))
    #Further split sentences on new lines
    post['sents'] = post['sents'].map(splitNewLine)
    post['sents'] = post['sents'].map(splitSemicolon)
    #Add a column with list (sentences) of list (words)
    post['words'] = post.sents.map(lambda x: [nltk.word_tokenize(sent) for sent in x])
    final = post[['text','sents','words']]
    final.to_pickle(path_to_output_df)
    return post

# %%
post = tokenizeCB(path.join(pardir, pardir, 'data','careerbuilder', 'cb_jobs_all_feb23.pkl'), 
                  path.join(pardir, pardir, 'data', 'careerbuilder', 'cb_jobs_all_processed_feb23.pkl'))
post.head()
# Out:
#                                                               raw_text  \
# DID
# JHM6MV6QVWPD9H699YB  &lt;div&gt;\n&lt;p align=&quot;justify&quot;&g...
# JHV3S36KLJXBR1S4110  DevOps Engineer.&amp;nbsp; We are looking for ...
# J3J3VQ6S25X4S6PHDKW  Accounts Payable Accountant&lt;br /&gt;&amp;nb...
# J3K0F76G1WZ91BCYP5Q  &lt;div&gt; &lt;p&gt;Another Source’s client, ...
# JHV8H75Z63QCTG3XT2K  &lt;p&gt;&lt;br /&gt;&lt;/p&gt;\n&lt;div style...
#
#                                                                   html  \
# DID
# JHM6MV6QVWPD9H699YB  <div>\n<p align="justify"><strong>GARDAWORLD</...
# JHV3S36KLJXBR1S4110  DevOps Engineer.&nbsp; We are looking for a qu...
# J3J3VQ6S25X4S6PHDKW  Accounts Payable Accountant<br />&nbsp;<br />S...
# J3K0F76G1WZ91BCYP5Q  <div> <p>Another Source’s client, University o...
# JHV8H75Z63QCTG3XT2K  <p><br /></p>\n<div style="text-align: center"...
#
#                                                                   text  \
# DID
# JHM6MV6QVWPD9H699YB  \nGARDAWORLD , one of the nation's largest cas...
# JHV3S36KLJXBR1S4110  DevOps Engineer.\nWe are looking for a qualifi...
# J3J3VQ6S25X4S6PHDKW  Accounts Payable Accountant\nSupervise and coo...
# J3K0F76G1WZ91BCYP5Q  \nAnother Sources client, University of Califo...
# JHV8H75Z63QCTG3XT2K  \nAramark\nAramark delivers experiences that e...
#
#                                                                  sents  \
# DID
# JHM6MV6QVWPD9H699YB  [GARDAWORLD , one of the nation's largest cash...
# JHV3S36KLJXBR1S4110  [DevOps Engineer., We are looking for a qualif...
# J3J3VQ6S25X4S6PHDKW  [Accounts Payable Accountant, Supervise and co...
# J3K0F76G1WZ91BCYP5Q  [Another Sources client, University of Califor...
# JHV8H75Z63QCTG3XT2K  [Aramark, Aramark delivers experiences that en...
#
#                                                                  words
# DID
# JHM6MV6QVWPD9H699YB  [[GARDAWORLD, ,, one, of, the, nation, 's, lar...
# JHV3S36KLJXBR1S4110  [[DevOps, Engineer, .], [We, are, looking, for...
# J3J3VQ6S25X4S6PHDKW  [[Accounts, Payable, Accountant], [Supervise, ...
# J3K0F76G1WZ91BCYP5Q  [[Another, Sources, client, ,, University, of,...
# JHV8H75Z63QCTG3XT2K  [[Aramark], [Aramark, delivers, experiences, t...

# %%
post.sents[2000]
# Out:
# ['JOIN CAPSTONE LOGISTICS, LLC.',
#  "NOW DON'T MISS THIS OPPORTUNITY!",
#  'NOW HIRING A WAREHOUSE SUPERVISOR',
#  'Capstone Logistics is a fast growing exciting company focused on third party services in distribution centers across the nation.',
#  'We are in 45 states and over 250 Distribution Centers across the United States.',
#  'We are looking for a Warehouse Supervisor to join our team and be part of something great.',
#  'We have an outstanding career opportunity for a driven, successful Warehouse Supervisor with at least 3 years of increasing management responsibility in the distribution/transportation fields.',
#  'Successful candidates will handle the daily supervision of a warehouse crew.',
#  'We provide unloading services for our client.',
#  'Daily responsibilities',
#  '*Scheduling of personnel based on client-supplied schedules',
#  '*Negotiation of rates with common carrier representatives',
#  '*Running shift with safety and efficiency as priorities',
#  '*Writing and balancing daily bank deposits',
#  '*Creation of daily work logs and transmission of same to corporate',
#  '*Audit of daily labor and billing reports',
#  'Requirements',
#  'Excellent interpersonal communication, leadership, and customer service skills.',
#  'The ability to make decisions, problem solve, prioritize assignments and direct the workforce in an ever-changing, warehouse environment.',
#  'Intermediate computer experience, ideally with Microsoft products.',
#  'Excellent interpersonal communication, leadership and customer service skills',
#  'Proven track record in supervision of warehouse employees including Hiring &amp',
#  ' Training',
#  'Experience with managing budgets and ability to create &amp',
#  ' maintain various management reports.',
#  'Working Conditions: Requires ability to work until job is completed.',
#  'Physical requirements include walking, stooping, lifting up to 75 lbs.',
#  'and standing for extended periods of time.',
#  'This description portrays in general terms the type and levels of work performed and is not intended to be all-inclusive or to represent specific duties of any one incumbent.',
#  'The job responsibilities and tasks described herein may be modified and expanded over time .',
#  'TO APPLY:',
#  'Please visit our website, www.capstonelogistics.com',
#  'and enter requisition 4506 to apply.',
#  'This position offers a competitive salary, potential bonus and benefit package.',
#  'Capstone Logistics is an Equal Opportunity Employer committed to quality through diversity.',
#  'Capstone Logistics is a Drug- Free Workplace',
#  ' background check required.']
